# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
#Pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("E:/Internship/Personalized_Healthcare_System/notebooks/data/Medicine__data.csv")
df.head()
# Out:
#    Gender              Symptom               Causes          Disease  \
# 0    Male                Fever      Viral Infection      Common Cold
# 1  Female             Headache               Stress         Migraine
# 2    Male  Shortness of Breath            Pollution           Asthma
# 3  Female               Nausea       Food Poisoning  Gastroenteritis
# 4    Male          Sore Throat  Bacterial Infection     Strep Throat
#
#             Medicine
# 0          Ibuprofen
# 1        Sumatriptan
# 2  Albuterol Inhaler
# 3   Oral Rehydration
# 4         Penicillin

# %%
x=df.drop(labels=["Medicine"],axis=1)
y=df["Medicine"]

# %%
x
# Out:
#      Gender              Symptom                Causes               Disease
# 0      Male                Fever       Viral Infection           Common Cold
# 1    Female             Headache                Stress              Migraine
# 2      Male  Shortness of Breath             Pollution                Asthma
# 3    Female               Nausea        Food Poisoning       Gastroenteritis
# 4      Male          Sore Throat   Bacterial Infection          Strep Throat
# ..      ...                  ...                   ...                   ...
# 236  Female                Cough  COVID-19 Exposure           COVID-19
# 237    Male              Itching  Allergies             Allergic Reaction An
# 238  Female          Muscle Pain  Overexertion               Muscle Strain
# 239    Male               Nausea      Food Poisoning         Muscle Strain
# 240  Female             Headache  Eye Strain                 Muscle Strain
#
# [241 rows x 4 columns]

# %%
y
# Out:
# 0              Ibuprofen
# 1            Sumatriptan
# 2      Albuterol Inhaler
# 3       Oral Rehydration
# 4             Penicillin
#              ...
# 236            Isolation
# 237          tihistamine
# 238                 Rest
# 239          Rehydration
# 240        Eye Exercises
# Name: Medicine, Length: 241, dtype: object

# %%
categorical_features = x.select_dtypes(include=['object']).columns

# %%
categorical_features
# Out:
# Index(['Gender', 'Symptom', 'Causes', 'Disease'], dtype='object')

# %%
gender_list = ['Male', 'Female']
symptom_list = ['Fever', 'Headache', 'Shortness of Breath' ,'Nausea' ,'Sore Throat','Joint Pain', 'Chest Pain' ,'Itching' ,'Abdominal Pain' ,'Fatigue' ,'Cough','Stomach Pain' ,'Back Pain' ,'Anxiety' ,'Skin Rash' ,'Dizziness','Muscle Pain' ,' Back Pain']
cause_list = ['Viral Infection', 'Stress', 'Pollution', 'Food Poisoning','Bacterial Infection', 'Rheumatoid Arthritis','High Blood Pressure', 'Allergies', 'Poor Diet', 'Depression','Cold Weather', 'Motion Sickness', 'Smoking', 'Migraine Triggers','Spicy Food', 'Autoimmune Response', 'Herniated Disc', 'Pregnancy','Anemia', 'Obesity', 'Osteoarthritis', 'Dehydration', 'Tension','vereating            ', 'Menstrual Cycle', 'Heart Disease','Hypothyroidism', 'Infection', 'COVID-19 Exposure', 'Overexertion','Eye Strain', 'Sciatica', 'Chronic Fatigue Syndrome','Physical Exertion', 'COVID-19 exposure', 'Overeating','Chronic Fatigue', ' COVID-19 Exposure','Chronic Fatigue Syndrome', 'Bacterial Infection ','Anemia              ', 'Stress              ','Obesity             ', 'Allergies           ','Viral Infection     ', 'Rheumatoid Arthritis ','Dehydration         ', 'Tension             ','Overeating          ', 'Menstrual Cycle    ','Heart Disease       ', 'Hypothyroidism      ','Infection           ', 'COVID-19 Exposure   ','Overexertion        ', 'Food Poisoning  ', 'Eye Strain          ']
disease_list = ['Common Cold', 'Migraine', 'Asthma', 'Gastroenteritis','Strep Throat', 'Arthritis', 'Hypertension', 'Allergic Reaction','Indigestion', 'Major Depressive', 'Influenza', 'Motion Sickness','Chronic Bronchitis', 'Gastritis', 'Rheumatoid Arthritis','Tonsillitis', 'Sciatica', 'Morning Sickness', 'Iron Deficiency','Panic Disorder', 'Sleep Apnea', 'Dermatitis','Respiratory infection', 'Heat Exhaustion', 'Tension Headache','Menstrual Cramps', 'Coronary ArteryDisease', 'Thyroid Disorder','Pneumonia', 'COVID-19', 'Muscle Strain', 'Vision Fatigue','Herniated Disc', 'Chronic Fatigue Syndrome', 'Anxiety Disorder','Muscle Overuse', 's  Arthritis', 'Major Depressive Disorder','Allergic Reacti', 'Chronic Fatigue', ' Arthritis','RespiratoryInfection', 'Coronary Artery', 'is  Arthritis','Respiratory Infection', 'Coronary Artery Disease', 'Respiratory','Strep Throat     ', 'Iron Deficiency ', 'Panic Disorder  ','Sleep Apnea     ', 'Dermatitis      ','Respiratory     AntiInfection', 'Arthritis     ','Heat Exhaustion Hydr', 'Tension Headache Rel','Indigestion     Anta', 'Menstrual Cramps Pai','Coronary Artery Disease   ', 'Disease         ','Pheumonia      ', 'COVID-19      ', 'Allergic Reaction An','Muscle Strain  ']

# %%
categorical_pipeline=Pipeline(

    steps=[
        ("Imputer",SimpleImputer(strategy='most_frequent')),
        ("OneHotEncoder",OneHotEncoder(handle_unknown='ignore',sparse_output=False)),
        ("StandardScaler",StandardScaler())      

    ]
)

# %%
preprocessor=ColumnTransformer(
    [
        ("Cat_Pipeline",categorical_pipeline,categorical_features),
    ]
)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
preprocessor.fit_transform(x_train)
# Out:
# array([[ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         13.82027496, -0.07235746],
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        ...,
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [-1.05351322,  1.05351322, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746]], shape=(192, 118))

# %%
preprocessor.transform(x_test)
# Out:
# array([[-1.05351322,  1.05351322, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [-1.05351322,  1.05351322, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        ...,
#        [-1.05351322,  1.05351322, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [-1.05351322,  1.05351322, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746],
#        [ 0.94920498, -0.94920498, -0.07235746, ..., -0.20851441,
#         -0.07235746, -0.07235746]], shape=(49, 118))

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['Cat_Pipeline__Gender_Female', 'Cat_Pipeline__Gender_Male',
#        'Cat_Pipeline__Symptom_ Back Pain',
#        'Cat_Pipeline__Symptom_Abdominal Pain',
#        'Cat_Pipeline__Symptom_Anxiety', 'Cat_Pipeline__Symptom_Back Pain',
#        'Cat_Pipeline__Symptom_Chest Pain', 'Cat_Pipeline__Symptom_Cough',
#        'Cat_Pipeline__Symptom_Dizziness', 'Cat_Pipeline__Symptom_Fatigue',
#        'Cat_Pipeline__Symptom_Fever', 'Cat_Pipeline__Symptom_Headache',
#        'Cat_Pipeline__Symptom_Itching',
#        'Cat_Pipeline__Symptom_Joint Pain',
#        'Cat_Pipeline__Symptom_Muscle Pain',
#        'Cat_Pipeline__Symptom_Nausea',
#        'Cat_Pipeline__Symptom_Shortness of Breath',
#        'Cat_Pipeline__Symptom_Skin Rash',
#        'Cat_Pipeline__Symptom_Sore Throat',
#        'Cat_Pipeline__Symptom_Stomach Pain',
#        'Cat_Pipeline__Causes_ COVID-19 Exposure',
#        'Cat_Pipeline__Causes_Allergies',
#        'Cat_Pipeline__Causes_Allergies           ',
#        'Cat_Pipeline__Causes_Anemia',
#        'Cat_Pipeline__Causes_Anemia              ',
#        'Cat_Pipeline__Causes_Bacterial Infection',
#        'Cat_Pipeline__Causes_COVID-19 Exposure',
#        'Cat_Pipeline__Causes_COVID-19 exposure',
#        'Cat_Pipeline__Causes_Chronic Fatigue',
#        'Cat_Pipeline__Causes_Chronic Fatigue Syndrome',
#        'Cat_Pipeline__Causes_Cold Weather',
#        'Cat_Pipeline__Causes_Dehydration',
#        'Cat_Pipeline__Causes_Dehydration         ',
#        'Cat_Pipeline__Causes_Depression',
#        'Cat_Pipeline__Causes_Eye Strain',
#        'Cat_Pipeline__Causes_Eye Strain          ',
#        'Cat_Pipeline__Causes_Food Poisoning',
#        'Cat_Pipeline__Causes_Food Poisoning  ',
#        'Cat_Pipeline__Causes_Heart Disease',
#        'Cat_Pipeline__Causes_Heart Disease       ',
#        'Cat_Pipeline__Causes_High Blood Pressure',
#        'Cat_Pipeline__Causes_Hypothyroidism',
#        'Cat_Pipeline__Causes_Hypothyroidism      ',
#        'Cat_Pipeline__Causes_Infection',
#        'Cat_Pipeline__Causes_Infection           ',
#        'Cat_Pipeline__Causes_Menstrual Cycle',
#        'Cat_Pipeline__Causes_Menstrual Cycle    ',
#        'Cat_Pipeline__Causes_Migraine Triggers',
#        'Cat_Pipeline__Causes_Motion Sickness',
#        'Cat_Pipeline__Causes_Obesity', 'Cat_Pipeline__Causes_Overeating',
#        'Cat_Pipeline__Causes_Overeating          ',
#        'Cat_Pipeline__Causes_Overexertion',
#        'Cat_Pipeline__Causes_Physical Exertion',
#        'Cat_Pipeline__Causes_Pollution', 'Cat_Pipeline__Causes_Poor Diet',
#        'Cat_Pipeline__Causes_Rheumatoid Arthritis',
#        'Cat_Pipeline__Causes_Rheumatoid Arthritis ',
#        'Cat_Pipeline__Causes_Sciatica', 'Cat_Pipeline__Causes_Smoking',
#        'Cat_Pipeline__Causes_Stress',
#        'Cat_Pipeline__Causes_Stress              ',
#        'Cat_Pipeline__Causes_Tension',
#        'Cat_Pipeline__Causes_Tension             ',
#        'Cat_Pipeline__Causes_Viral Infection',
#        'Cat_Pipeline__Causes_tCOVID-19 exposure',
#        'Cat_Pipeline__Causes_vereating            ',
#        'Cat_Pipeline__Disease_ Arthritis',
#        'Cat_Pipeline__Disease_Allergic Reacti',
#        'Cat_Pipeline__Disease_Allergic Reaction',
#        'Cat_Pipeline__Disease_Allergic Reaction An',
#        'Cat_Pipeline__Disease_Anxiety Disorder',
#        'Cat_Pipeline__Disease_Arthritis',
#        'Cat_Pipeline__Disease_Arthritis     ',
#        'Cat_Pipeline__Disease_Asthma', 'Cat_Pipeline__Disease_COVID-19',
#        'Cat_Pipeline__Disease_Chronic Bronchitis',
#        'Cat_Pipeline__Disease_Chronic Fatigue',
#        'Cat_Pipeline__Disease_Chronic Fatigue Syndrome',
#        'Cat_Pipeline__Disease_Common Cold',
#        'Cat_Pipeline__Disease_Coronary Artery',
#        'Cat_Pipeline__Disease_Coronary Artery Disease',
#        'Cat_Pipeline__Disease_Coronary Artery Disease   ',
#        'Cat_Pipeline__Disease_Dermatitis',
#        'Cat_Pipeline__Disease_Dermatitis      ',
#        'Cat_Pipeline__Disease_Disease         ',
#        'Cat_Pipeline__Disease_Gastroenteritis',
#        'Cat_Pipeline__Disease_Heat Exhaustion',
#        'Cat_Pipeline__Disease_Heat Exhaustion Hydr',
#        'Cat_Pipeline__Disease_Herniated Disc',
#        'Cat_Pipeline__Disease_Hypertension',
#        'Cat_Pipeline__Disease_Indigestion',
#        'Cat_Pipeline__Disease_Indigestion     Anta',
#        'Cat_Pipeline__Disease_Iron Deficiency',
#        'Cat_Pipeline__Disease_Iron Deficiency ',
#        'Cat_Pipeline__Disease_Major Depressive Disorder',
#        'Cat_Pipeline__Disease_Menstrual Cramps',
#        'Cat_Pipeline__Disease_Menstrual Cramps Pai',
#        'Cat_Pipeline__Disease_Migraine',
#        'Cat_Pipeline__Disease_Motion Sickness',
#        'Cat_Pipeline__Disease_Muscle Overuse',
#        'Cat_Pipeline__Disease_Muscle Strain',
#        'Cat_Pipeline__Disease_Muscle Strain  ',
#        'Cat_Pipeline__Disease_Panic Disorder',
#        'Cat_Pipeline__Disease_Panic Disorder  ',
#        'Cat_Pipeline__Disease_Pheumonia      ',
#        'Cat_Pipeline__Disease_Pneumonia',
#        'Cat_Pipeline__Disease_Respiratory Infection',
#        'Cat_Pipeline__Disease_RespiratoryInfection',
#        'Cat_Pipeline__Disease_Sleep Apnea',
#        'Cat_Pipeline__Disease_Strep Throat',
#        'Cat_Pipeline__Disease_Tension Headache',
#        'Cat_Pipeline__Disease_Tension Headache Rel',
#        'Cat_Pipeline__Disease_Thyroid Disorder',
#        'Cat_Pipeline__Disease_Tonsillitis',
#        'Cat_Pipeline__Disease_Vision Fatigue',
#        'Cat_Pipeline__Disease_is  Arthritis',
#        'Cat_Pipeline__Disease_s  Arthritis'], dtype=object)

# %%
x_train=pd.DataFrame(preprocessor.fit_transform(x_train),columns=preprocessor.get_feature_names_out())
x_test=pd.DataFrame(preprocessor.transform(x_test),columns=preprocessor.get_feature_names_out())

# %%
x_test.head()
# Out:
#    Cat_Pipeline__Gender_Female  Cat_Pipeline__Gender_Male  \
# 0                    -1.053513                   1.053513
# 1                    -1.053513                   1.053513
# 2                     0.949205                  -0.949205
# 3                     0.949205                  -0.949205
# 4                     0.949205                  -0.949205
#
#    Cat_Pipeline__Symptom_ Back Pain  Cat_Pipeline__Symptom_Abdominal Pain  \
# 0                         -0.072357                             -0.208514
# 1                         -0.072357                             -0.208514
# 2                         -0.072357                             -0.208514
# 3                         -0.072357                             -0.208514
# 4                         -0.072357                             -0.208514
#
#    Cat_Pipeline__Symptom_Anxiety  Cat_Pipeline__Symptom_Back Pain  \
# 0                      -0.269492                        -0.163517
# 1                      -0.269492                        -0.163517
# 2                      -0.269492                        -0.163517
# 3                      -0.269492                        -0.163517
# 4                      -0.269492                        -0.163517
#
#    Cat_Pipeline__Symptom_Chest Pain  Cat_Pipeline__Symptom_Cough  \
# 0                         -0.280449                     4.266146
# 1                          3.565710                    -0.234404
# 2                         -0.280449                    -0.234404
# 3                         -0.280449                    -0.234404
# 4                         -0.280449                     4.266146
#
#    Cat_Pipeline__Symptom_Dizziness  Cat_Pipeline__Symptom_Fatigue  ...  \
# 0                        -0.163517                      -0.377964  ...
# 1                        -0.163517                      -0.377964  ...
# 2                        -0.163517                      -0.377964  ...
# 3                        -0.163517                      -0.377964  ...
# 4                        -0.163517                      -0.377964  ...
#
#    Cat_Pipeline__Disease_RespiratoryInfection  \
# 0                                   -0.072357
# 1                                   -0.072357
# 2                                   -0.072357
# 3                                   -0.072357
# 4                                   -0.072357
#
#    Cat_Pipeline__Disease_Sleep Apnea  Cat_Pipeline__Disease_Strep Throat  \
# 0                          -0.102598                           -0.125988
# 1                          -0.102598                           -0.125988
# 2                          -0.102598                           -0.125988
# 3                          -0.102598                           -0.125988
# 4                          -0.102598                           -0.125988
#
#    Cat_Pipeline__Disease_Tension Headache  \
# 0                               -0.125988
# 1                               -0.125988
# 2                               -0.125988
# 3                               -0.125988
# 4                               -0.125988
#
#    Cat_Pipeline__Disease_Tension Headache Rel  \
# 0                                   -0.072357
# 1                                   -0.072357
# 2                                   -0.072357
# 3                                   -0.072357
# 4                                   -0.072357
#
#    Cat_Pipeline__Disease_Thyroid Disorder  Cat_Pipeline__Disease_Tonsillitis  \
# 0                               -0.145865                           -0.19452
# 1                               -0.145865                           -0.19452
# 2                               -0.145865                           -0.19452
# 3                               -0.145865                           -0.19452
# 4                               -0.145865                           -0.19452
#
#    Cat_Pipeline__Disease_Vision Fatigue  Cat_Pipeline__Disease_is  Arthritis  \
# 0                             -0.208514                            -0.072357
# 1                             -0.208514                            -0.072357
# 2                             -0.208514                            -0.072357
# 3                             -0.208514                            -0.072357
# 4                             -0.208514                            -0.072357
#
#    Cat_Pipeline__Disease_s  Arthritis
# 0                           -0.072357
# 1                           -0.072357
# 2                           -0.072357
# 3                           -0.072357
# 4                           -0.072357
#
# [5 rows x 118 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
models={
    "RandomForestClassifier":RandomForestClassifier(n_estimators=100,random_state=42),
    "KNeighborsClassifier":KNeighborsClassifier(n_neighbors=3)
}

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(x_train,y_train)

    y_pred=model.predict(x_test)
    acc_m1 = accuracy_score(y_test, y_pred)
    print(f"Accuracy of {model} is {acc_m1}")
    print("--------------------------------------------------")
    
    print('='*33)
    print('\n')
# Out:
# Accuracy of RandomForestClassifier(random_state=42) is 0.8775510204081632
# --------------------------------------------------
# =================================
#
#
# Accuracy of KNeighborsClassifier(n_neighbors=3) is 0.6938775510204082
# --------------------------------------------------
# =================================
